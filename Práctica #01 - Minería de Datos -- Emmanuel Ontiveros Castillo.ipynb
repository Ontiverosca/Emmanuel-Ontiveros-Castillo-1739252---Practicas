# %% [markdown]
# # Práctica #01 - Minería de Datos -- Emmanuel Ontiveros Castillo

# %% [markdown]
# ## Preparando los datos

# %% [markdown]
#     Importando librerias

# %%
import pandas as pd
import numpy as np
import json

# %% [markdown]
#     Mandando a llamar/leer el archivo

# %%
datos = pd.read_csv("C:\\Users\\Kradn\\OneDrive\\Escritorio\\archivo.csv")

# %% [markdown]
# ## Visualización de datos

# %%
datos.head() #Muestra los primeros 5 registros.
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
datos.tail(3) #Muestra los primeros 5 registros. La cantidad se puede modificar poniendo un número dentro de los paréntesis,siempre y cuando no sobrepase de los registros.
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 11                            Superman Returns?ÿ                     434
# 12                           Quantum of Solace?ÿ                     403
# 13  Pirates of the Caribbean: Dead Man's Chest?ÿ                     313
#
#     duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 11     169.0                     NaN                     903
# 12     106.0                     395                     393
# 13     151.0                     563                    1000
#
#     ACTOR_1_facebook_likes      gross  num_voted_users  \
# 11                   18000  200069408         240396.0
# 12                     451  168368427         330784.0
# 13                   40000  423032628         522040.0
#
#     Cast_Total_facebook_likes  facenumber_in_poster  num_user_for_reviews  \
# 11                        NaN                   2.0                  2367
# ...

# %%
datos.columns #Enlista las columnas del csv
# Out:
# Index(['movie_title', 'num_critic_for_reviews', 'duration',
#        'DIRECTOR_facebook_likes', 'actor_3_facebook_likes',
#        'ACTOR_1_facebook_likes', 'gross', 'num_voted_users',
#        'Cast_Total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'title_year',
#        'ACTOR_2_facebook_likes', 'imdb_score', 'title_year.1'],
#       dtype='object')

# %%
datos.rename(columns = {'ACTOR_1_facebook_likes':'ActorFB'})
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %%
datos.dtypes #Enlista el tipo de dato de la columna
# Out:
# movie_title                   object
# num_critic_for_reviews         int64
# duration                     float64
# DIRECTOR_facebook_likes       object
# actor_3_facebook_likes         int64
# ACTOR_1_facebook_likes         int64
# gross                          int64
# num_voted_users              float64
# Cast_Total_facebook_likes    float64
# facenumber_in_poster         float64
# num_user_for_reviews           int64
# budget                         int64
# title_year                     int64
# ACTOR_2_facebook_likes       float64
# imdb_score                   float64
# title_year.1                 float64
# dtype: object

# %%
datos['duration'].dtype #Nos muestra el tipo de dato que contiene una columna en específico.
# Out:
# dtype('float64')

# %%
datos.title_year.astype("float") #Normaliza los datos de la columna a datos flotantes
# Out:
# 0     2009.0
# 1     2007.0
# 2     2015.0
# 3     2012.0
# 4     2012.0
# 5     2007.0
# 6     2010.0
# 7     2015.0
# 8     2015.0
# 9     2009.0
# 10    2016.0
# 11    2006.0
# 12    2008.0
# 13    2006.0
# Name: title_year, dtype: float64

# %%
datos.budget.unique() #Muestra los datos unicos y no los repetidos
# Out:
# array([237000000, 300000000, 245000000, 250000000, 263700000, 258000000,
#        260000000, 209000000, 200000000, 225000000], dtype=int64)

# %%
cla = datos[datos['DIRECTOR_facebook_likes']=='10'] #Se están agrupando los datos de 26000

cla.to_csv('Solo_clase1.csv', index=False) #Aqui se van a guardar las agreupaciones

# %%
datos.drop('title_year.1',axis = 1 ) #Con esta sentencia se elimina una columna que no necesitemos.
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %% [markdown]
#     ¿Para que me puede servir estas agrupaciones para la práctica siguiente?
#         Se puede utilizar para tener un control de los datos y poder modificar a necesidad nuestra base de datos.

# %% [markdown]
# ## Datos nulos

# %%
datos.isnull() #Hace un análisis de los valores faltantes
# Out:
#     movie_title  num_critic_for_reviews  duration  DIRECTOR_facebook_likes  \
# 0         False                   False     False                    False
# 1         False                   False      True                    False
# 2         False                   False     False                    False
# 3         False                   False      True                    False
# 4         False                   False     False                    False
# 5         False                   False     False                    False
# 6         False                   False      True                    False
# 7         False                   False     False                    False
# 8         False                   False     False                    False
# 9         False                   False     False                    False
# 10        False                   False     False                     True
# ...

# %%
datos.isnull().any() #Nos da las columnas y se nos dice si en ella hay valores vacíos
# Out:
# movie_title                  False
# num_critic_for_reviews       False
# duration                      True
# DIRECTOR_facebook_likes       True
# actor_3_facebook_likes       False
# ACTOR_1_facebook_likes       False
# gross                        False
# num_voted_users               True
# Cast_Total_facebook_likes     True
# facenumber_in_poster          True
# num_user_for_reviews         False
# budget                       False
# title_year                   False
# ACTOR_2_facebook_likes        True
# imdb_score                   False
# title_year.1                  True
# dtype: bool

# %%
datos.isnull().sum() #Te da el total de cuatos datos vacíos hay en cada columna.
# Out:
# movie_title                  0
# num_critic_for_reviews       0
# duration                     3
# DIRECTOR_facebook_likes      2
# actor_3_facebook_likes       0
# ACTOR_1_facebook_likes       0
# gross                        0
# num_voted_users              1
# Cast_Total_facebook_likes    2
# facenumber_in_poster         5
# num_user_for_reviews         0
# budget                       0
# title_year                   0
# ACTOR_2_facebook_likes       1
# imdb_score                   0
# title_year.1                 7
# dtype: int64

# %% [markdown]
#     Importancia del analisis previo de los datos antes de iniciar las modificaciones.
#         Es importante para poder llevar un control de con lo que se quiere trbajar y saber que cosas se van a tener que eliminar o agregar, tambi´pen depende mucho del dato,porque si los cambia ya no será el mismo resultado para la técnica que va a utilizar y saber cuales tienes que normalizar.

# %%
datos_0 = datos.fillna(0) #Con esta instruccion se rellenarán con 0 las celdas nulas o vacías

# %%
datos_drop = datos.dropna() #Con esta instruccion se eliminan las filas que contengan datos nuloso vacíos. En este progreso que tengo no lo hará porque ya los rellené :)

# %%
datos_drop_column = datos.dropna(axis=1) ##Con esta instruccion se eliminan las columnas que contengan datos nuloso vacíos. En este progreso que tengo no lo hará porque ya los rellené :)

# %%
datos.head(17)
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %% [markdown]
# ### Tareas extra

# %% [markdown]
#  #### Investigar los siguientes comandos: ?df.dropna() ?df.astype
#          La función dropna () se usa para eliminar los valores faltantes.
#
#          La función astype () también proporciona la capacidad de convertir cualquier columna existente adecuada a tipo categórico.
